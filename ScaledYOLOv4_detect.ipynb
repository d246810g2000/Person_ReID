# %% [markdown]
# # 物件偵測專班

# %% [markdown]
# # YOLOv4 預測教學

# %% [markdown]
# ## 匯入所需套件

# %%
import argparse
import os
import platform
import shutil
import numpy as np
import pandas as pd
import time
from pathlib import Path

import cv2
import torch
import torch.backends.cudnn as cudnn
from numpy import random

from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import (
    check_img_size, non_max_suppression, apply_classifier, scale_coords, xyxy2xywh, plot_one_box, strip_optimizer)
from utils.torch_utils import select_device, load_classifier, time_synchronized

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## 參數設置

# %%
weights = 'runs/exp11_yolov4-csp/weights/best_yolov4-csp.pt'
source = '../person_reid_datasets/test/'
sub = '../person_reid_datasets/sample_submission.csv'
out = 'inference/output'
imgsz = 640
conf_thres = 0.25
iou_thres = 0.5

# %%
# 創建資料夾
if os.path.exists(out):
    shutil.rmtree(out)  # delete output folder
os.makedirs(out)  # make new output folder

# %%
model = attempt_load(weights, map_location=device)  # load FP32 model
imgsz = check_img_size(imgsz, s=model.stride.max())  # check img_size
# Out:
# Fusing layers... Model Summary: 235 layers, 5.24706e+07 parameters, 5.04494e+07 gradients

# %%
import torch.nn as nn
from torchvision import models

# Defines the new fc layer and classification layer
# |--Linear--|--bn--|--relu--|--Linear--|
class ClassBlock(nn.Module):
    def __init__(self, input_dim, class_num, droprate, relu=False, bnorm=True, linear=512, return_f = False):
        super(ClassBlock, self).__init__()
        self.return_f = return_f
        add_block = []
        if linear>0:
            add_block += [nn.Linear(input_dim, linear)]
        else:
            linear = input_dim
        if bnorm:
            add_block += [nn.BatchNorm1d(linear)]
        if relu:
            add_block += [nn.LeakyReLU(0.1)]
        if droprate>0:
            add_block += [nn.Dropout(p=droprate)]
        add_block = nn.Sequential(*add_block)
        
        classifier = []
        classifier += [nn.Linear(linear, class_num)]
        classifier = nn.Sequential(*classifier)

        self.add_block = add_block
        self.classifier = classifier
    def forward(self, x):
        x = self.add_block(x)
        if self.return_f:
            f = x
            x = self.classifier(x)
            return [x,f]
        else:
            x = self.classifier(x)
            return x
        
class ft_net(nn.Module):
    def __init__(self, class_num=100, droprate=0.5, circle=False, linear_num=512):
        super(ft_net, self).__init__()
        model_ft = models.resnet50(pretrained=True)
        self.model = nn.Sequential(*list(model_ft.children())[:-1])
        self.classifier = ClassBlock(2048, class_num, droprate, linear=linear_num, return_f = circle)

    def forward(self, x):
        x = self.model(x)
        x = x.view(x.size(0), x.size(1))
        x = self.classifier(x)
        return x
    
reid_model = torch.load('../reid_model.pth')

# %% [markdown]
# ## 預測影像

# %%
dataset = LoadImages(source, img_size=imgsz)

# %%
class_names = ['1',
 '111',
 '112',
 '116',
 '117',
 '122',
 '123',
 '124',
 '125',
 '126',
 '132',
 '133',
 '135',
 '148',
 '15',
 '155',
 '162',
 '163',
 '166',
 '173',
 '174',
 '175',
 '181',
 '182',
 '183',
 '184',
 '185',
 '188',
 '192',
 '193',
 '197',
 '205',
 '216',
 '221',
 '222',
 '225',
 '228',
 '230',
 '231',
 '232',
 '233',
 '235',
 '265',
 '273',
 '285',
 '296',
 '3',
 '302',
 '338',
 '339',
 '341',
 '344',
 '359',
 '516',
 '517',
 '543',
 '544',
 '545',
 '55',
 '607',
 '61',
 '618',
 '619',
 '621',
 '622',
 '623',
 '624',
 '626',
 '63',
 '652',
 '653',
 '655',
 '656',
 '659',
 '660',
 '662',
 '663',
 '664',
 '705',
 '712',
 '713',
 '714',
 '734',
 '735',
 '736',
 '74',
 '75',
 '754',
 '835',
 '84',
 '857',
 '87',
 '88',
 '880',
 '881',
 '882',
 '891',
 '894',
 '90',
 '98']
colors = [[random.randint(0, 255) for _ in range(3)] for _ in range(len(class_names))]

# %%
submission = pd.read_csv(sub)
submission = submission.drop([0])
# Run inference
with torch.no_grad():
    t0 = time.time()
    img = torch.zeros((1, 3, imgsz, imgsz), device=device)  # init img
    _ = model(img) # run once
    for path, img, im0s, vid_cap in dataset:
        basename = os.path.basename(path)
        basename_no_ext = os.path.splitext(basename)[0]
        
        h, w, _ = im0s.shape
        img = torch.from_numpy(img).to(device)
        img = img.float()  # uint8 to fp16/32
        img /= 255.0  # 0 - 255 to 0.0 - 1.0
        if img.ndimension() == 3:
            img = img.unsqueeze(0)
        # Inference
        t1 = time_synchronized()
        pred = model(img)[0]

        # Apply NMS
        pred = non_max_suppression(pred, conf_thres, iou_thres)
        t2 = time_synchronized()

        # Process detections
        for i, det in enumerate(pred):  # detections per image
            p, s, im0 = path, '', im0s
            save_path = str(Path(out) / Path(p).name)
            s += '%gx%g ' % img.shape[2:]  # print string
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            if det is not None and len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += '%g' % n  # add to string

                # Write results
                for *xyxy, conf, cls in det:
                    crop_img = im0[int(xyxy[1]):int(xyxy[3]), int(xyxy[0]):int(xyxy[2])]
                    crop_img_resize = cv2.resize(crop_img[:,:,::-1], (224, 224))
                    crop_img_resize = ((crop_img_resize/255 - (0.485, 0.456, 0.406)) / (0.229, 0.224, 0.225)).astype('float32') # 0 - 255 to 0.0 - 1.0
                    crop_img_resize = crop_img_resize.transpose((2, 0, 1))
                    crop_img_resize = np.expand_dims(crop_img_resize, 0)
                    crop_img_resize = torch.from_numpy(crop_img_resize).to(device)
                    reid_model.eval()
                    with torch.no_grad():
                        outputs, _ = reid_model(crop_img_resize)
                        _, preds = torch.max(outputs, 1)
                    reid = class_names[preds[0]]
                    submission.loc[len(submission)] = [basename_no_ext,
                                                       reid,
                                                       float(conf.cpu()),
                                                       int(xyxy[0].cpu())/w,
                                                       int(xyxy[1].cpu())/h,
                                                       int(xyxy[2].cpu())/w,
                                                       int(xyxy[3].cpu())/h]
            print(s)
#                     plot_one_box(xyxy, im0, label=reid, color=colors[class_names.index(reid)], line_thickness=1)
#             cv2.imwrite(save_path, im0)
    print('Results saved to %s' % Path(out))
    print('Done. (%.3fs)' % (time.time() - t0))
# Out:
# image 1/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_01.jpg: 384x640 5
# image 2/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_02.jpg: 384x640 3
# image 3/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_03.jpg: 384x640 4
# image 4/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_04.jpg: 384x640 4
# image 5/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_05.jpg: 384x640 2
# image 6/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_06.jpg: 384x640 4
# image 7/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_07.jpg: 384x640 5
# image 8/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_08.jpg: 384x640 4
# image 9/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_09.jpg: 384x640 8
# image 10/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_10.jpg: 384x640 3
# image 11/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_11.jpg: 384x640 4
# image 12/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_12.jpg: 384x640 4
# image 13/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_13.jpg: 384x640 2
# image 14/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_14.jpg: 384x640 1
# image 15/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_15.jpg: 384x640 2
# image 16/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_16.jpg: 384x640 1
# image 17/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_17.jpg: 384x640 3
# image 18/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_18.jpg: 384x640 3
# image 19/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_19.jpg: 384x640 3
# image 20/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_20.jpg: 384x640 3
# image 21/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_21.jpg: 384x640 4
# image 22/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_22.jpg: 384x640 1
# image 23/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_23.jpg: 384x640 4
# image 24/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_24.jpg: 384x640 2
# image 25/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_25.jpg: 384x640 1
# image 26/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_26.jpg: 384x640 2
# image 27/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_27.jpg: 384x640 3
# image 28/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_28.jpg: 384x640 4
# image 29/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_29.jpg: 384x640 1
# image 30/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_30.jpg: 384x640 4
# image 31/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_31.jpg: 384x640 1
# image 32/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_32.jpg: 384x640 1
# image 33/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_33.jpg: 384x640 3
# image 34/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_34.jpg: 384x640 5
# image 35/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_35.jpg: 384x640 3
# image 36/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_36.jpg: 384x640 2
# image 37/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_37.jpg: 384x640 2
# image 38/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_38.jpg: 384x640 1
# image 39/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_39.jpg: 384x640 4
# image 40/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_40.jpg: 384x640 2
# image 41/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_41.jpg: 384x640 1
# image 42/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_42.jpg: 384x640 6
# image 43/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_43.jpg: 384x640 3
# image 44/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_44.jpg: 384x640 4
# image 45/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_45.jpg: 384x640 2
# image 46/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_46.jpg: 384x640 1
# image 47/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_47.jpg: 384x640 7
# image 48/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_48.jpg: 384x640 5
# image 49/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_49.jpg: 384x640 4
# image 50/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_50.jpg: 384x640 2
# image 51/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_51.jpg: 384x640 2
# image 52/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_52.jpg: 384x640 2
# image 53/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_53.jpg: 384x640 1
# image 54/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_54.jpg: 384x640 2
# image 55/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_55.jpg: 384x640 1
# image 56/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_56.jpg: 384x640 2
# image 57/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_57.jpg: 384x640 1
# image 58/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_58.jpg: 384x640 5
# image 59/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_59.jpg: 384x640 3
# image 60/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_60.jpg: 384x640 7
# image 61/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_61.jpg: 384x640 1
# image 62/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_62.jpg: 384x640 3
# image 63/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_63.jpg: 384x640 2
# image 64/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_64.jpg: 384x640 3
# image 65/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_65.jpg: 384x640 3
# image 66/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_66.jpg: 384x640 1
# image 67/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_67.jpg: 384x640 3
# image 68/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_68.jpg: 384x640 1
# image 69/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_69.jpg: 384x640 3
# image 70/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_70.jpg: 384x640 4
# image 71/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_71.jpg: 384x640 2
# image 72/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c1_72.jpg: 384x640 4
# image 73/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_01.jpg: 384x640 2
# image 74/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_02.jpg: 384x640 2
# image 75/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_03.jpg: 384x640 2
# image 76/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_04.jpg: 384x640 1
# image 77/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_05.jpg: 384x640 1
# image 78/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_06.jpg: 384x640 2
# image 79/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_07.jpg: 384x640 2
# image 80/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_08.jpg: 384x640 2
# image 81/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_09.jpg: 384x640 2
# image 82/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_10.jpg: 384x640 3
# image 83/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_11.jpg: 384x640
# image 84/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_12.jpg: 384x640 2
# image 85/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_13.jpg: 384x640 1
# image 86/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_14.jpg: 384x640 2
# image 87/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_15.jpg: 384x640 1
# image 88/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_16.jpg: 384x640
# image 89/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_17.jpg: 384x640 4
# image 90/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_18.jpg: 384x640 3
# image 91/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_19.jpg: 384x640 1
# image 92/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_20.jpg: 384x640 1
# image 93/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_21.jpg: 384x640 1
# image 94/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_22.jpg: 384x640 2
# image 95/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_23.jpg: 384x640 1
# image 96/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_24.jpg: 384x640 3
# image 97/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_25.jpg: 384x640 2
# image 98/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_26.jpg: 384x640 1
# image 99/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_27.jpg: 384x640 2
# image 100/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_28.jpg: 384x640 1
# image 101/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_29.jpg: 384x640
# image 102/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_30.jpg: 384x640 1
# image 103/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_31.jpg: 384x640 3
# image 104/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_32.jpg: 384x640 2
# image 105/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_33.jpg: 384x640 1
# image 106/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c2_34.jpg: 384x640 3
# image 107/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_01.jpg: 384x640 3
# image 108/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_02.jpg: 384x640 4
# image 109/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_03.jpg: 384x640 1
# image 110/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_04.jpg: 384x640 2
# image 111/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_05.jpg: 384x640 3
# image 112/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_06.jpg: 384x640 3
# image 113/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_07.jpg: 384x640 4
# image 114/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_08.jpg: 384x640 3
# image 115/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_09.jpg: 384x640 3
# image 116/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_10.jpg: 384x640 3
# image 117/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_11.jpg: 384x640 2
# image 118/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_12.jpg: 384x640 5
# image 119/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_13.jpg: 384x640 4
# image 120/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_14.jpg: 384x640 2
# image 121/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_15.jpg: 384x640 2
# image 122/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_16.jpg: 384x640 3
# image 123/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_17.jpg: 384x640 3
# image 124/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_18.jpg: 384x640 2
# image 125/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_19.jpg: 384x640 3
# image 126/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_20.jpg: 384x640 2
# image 127/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_21.jpg: 384x640 5
# image 128/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_22.jpg: 384x640 2
# image 129/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_23.jpg: 384x640 7
# image 130/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_24.jpg: 384x640 2
# image 131/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_25.jpg: 384x640 3
# image 132/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_26.jpg: 384x640 3
# image 133/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_27.jpg: 384x640 3
# image 134/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_28.jpg: 384x640 3
# image 135/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_29.jpg: 384x640 1
# image 136/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_30.jpg: 384x640 2
# image 137/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_31.jpg: 384x640 5
# image 138/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_32.jpg: 384x640 4
# image 139/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_33.jpg: 384x640 2
# image 140/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_34.jpg: 384x640 3
# image 141/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_35.jpg: 384x640 3
# image 142/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_36.jpg: 384x640 2
# image 143/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_37.jpg: 384x640 2
# image 144/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_38.jpg: 384x640 2
# image 145/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_39.jpg: 384x640 4
# image 146/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_40.jpg: 384x640 2
# image 147/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_41.jpg: 384x640 3
# image 148/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_42.jpg: 384x640 4
# image 149/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_43.jpg: 384x640 5
# image 150/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_44.jpg: 384x640 5
# image 151/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_45.jpg: 384x640 3
# image 152/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_46.jpg: 384x640 2
# image 153/153 /home/jovyan/object_detection_project/person_reid_datasets/test/c3_47.jpg: 384x640 3
# Results saved to inference/output
# Done. (11.935s)

# %%
submission.to_csv('submission.csv', index=False)
